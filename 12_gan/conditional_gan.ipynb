# %% [markdown]
# # Conditional GAN（cGAN）
#
# ---
# ## 目的
# Conditional GAN (cGAN) [1]を構築し，条件（クラスラベル）を指定して意図した画像を生成する仕組みを理解する．`gan.ipynb`のGANとの違いに注目する．
#
# [1] Mehdi Mirza and Simon Osindero, "Conditional Generative Adversarial Nets," arXiv, 2014.

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートしたのち，GPUを使用した計算が可能かどうかを確認する．

# %%
from time import time
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

# %% [markdown]
# ## ネットワークの構築
# `gan.ipynb`のGANは，潜在変数のみから画像を生成するため，どの数字が生成されるかを制御できませんでした．cGANは，Generator・Discriminatorの入力にクラスラベル（条件）を追加することで，指定したクラスの画像を生成できるようにした手法です．
#
# 具体的には，クラスラベルをone-hotベクトルに変換し，Generatorでは潜在変数と，Discriminatorでは画像とそれぞれチャネル方向に結合（concat）してから入力します．ネットワーク構造自体は，`gan.ipynb`のGeneratorの入力層のユニット数を`latent_dim + n_cls`に，Discriminatorの入力層のユニット数を`28*28 + n_cls`に変更するのみで，それ以外の層のサイズは同じです．

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=100, n_cls=10):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(latent_dim + n_cls, 256), nn.ReLU(inplace=True),
            nn.Linear(256, 28 * 28), nn.Sigmoid(),
        )

    def forward(self, z, c):
        z = torch.cat([z, c], dim=1)  # 潜在変数とクラス条件（one-hot）を結合する
        return self.layer(z)


class Discriminator(nn.Module):
    def __init__(self, n_cls=10):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(28 * 28 + n_cls, 256), nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
        )

    def forward(self, x, c):
        x = torch.cat([x, c], dim=1)  # 画像とクラス条件（one-hot）を結合する
        return self.layer(x)

# %% [markdown]
# ## データセットと最適化関数
# データセットにはMNISTを使用します．最適化関数・学習率は`gan.ipynb`と同じ設定を使用します．

# %%
mnist_data = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
train_loader = DataLoader(mnist_data, batch_size=100, shuffle=True)

latent_dim = 100
n_cls = 10
G = Generator(latent_dim=latent_dim, n_cls=n_cls).to(device)
D = Discriminator(n_cls=n_cls).to(device)
opt_g = torch.optim.Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
opt_d = torch.optim.Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %% [markdown]
# ## cGANの学習
# cGANでは，以下の誤差関数で学習を行います．
#
# $$\min_{G}\max_{D}V(D, G) = \mathbb{E}_{x\sim p_{data}(x)}\left[\log D(x|y)\right] + \mathbb{E}_{z\sim p(z)}\left[\log\left(1 - D(G(z|y)|y)\right)\right]$$
#
# ここで，$y$はクラスラベル（条件）です．`gan.ipynb`との違いは，実画像・生成画像をDiscriminatorへ入力する際に，対応するクラスラベル$y$を条件として一緒に入力する点のみです．これにより，Discriminatorは「本物か偽物か」に加えて「条件と画像が一致しているか」も加味して判定するようになり，結果としてGeneratorは指定した条件通りの画像を生成するように学習されます．

# %%
epoch_num = 50
n_critic = 1
criterion = nn.BCEWithLogitsLoss().to(device)

G.train()
D.train()
start = time()
for epoch in range(1, epoch_num + 1):
    for idx, (real_x, label) in enumerate(train_loader):
        real_x = real_x.view(real_x.size(0), -1).to(device)
        batch = real_x.size(0)
        onehot = F.one_hot(label, num_classes=n_cls).float().to(device)
        flag_real = torch.ones(batch, 1).to(device)
        flag_fake = torch.zeros(batch, 1).to(device)

        for _ in range(n_critic):
            z = torch.randn(batch, latent_dim).to(device)
            fake_x = G(z, onehot)

            out_real = D(real_x, onehot)
            out_fake = D(fake_x.detach(), onehot)
            dis_loss = criterion(out_real, flag_real) + criterion(out_fake, flag_fake)

            opt_d.zero_grad()
            dis_loss.backward()
            opt_d.step()

        z = torch.randn(batch, latent_dim).to(device)
        fake_x = G(z, onehot)
        out_gen = D(fake_x, onehot)
        gen_loss = criterion(out_gen, flag_real)

        opt_g.zero_grad()
        gen_loss.backward()
        opt_g.step()

    print(f'epoch: {epoch}, D loss: {dis_loss.item():.4f}, G loss: {gen_loss.item():.4f}, elapsed_time: {time() - start:.4f}')

# %% [markdown]
# ## 生成画像の確認
# 0〜9のクラスラベルをそれぞれ条件として与え，意図したクラスの画像が生成できているかを確認します．

# %%
c = np.arange(10, dtype=np.int64)
onehot = F.one_hot(torch.from_numpy(c), num_classes=n_cls).float().to(device)
z = torch.randn(len(c), latent_dim).to(device)

G.eval()
with torch.no_grad():
    test_img = G(z, onehot)

test_img = test_img.view(len(c), 28, 28).cpu().numpy()

fig = plt.figure(figsize=(10, 2))
for i, im in enumerate(test_img):
    ax = fig.add_subplot(1, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(im, cmap='gray')
    ax.set_title(str(c[i]))
plt.show()

# %% [markdown]
# ## 課題
#
# 1. 条件を固定して潜在変数を線形補間したとき，どのような変化が現れるか確認してください．生成画像AからBへの線形補間は，$[0, 1]$で線形増加する値$\alpha$を用いて以下の式で表せます．
# $$
# \hat{z} = (1-\alpha)\cdot z_{A} + \alpha\cdot z_{B}, \quad I_{A\rightarrow B} = G(\hat{z}, y)
# $$
# 2. 潜在変数を固定して条件のみを変化させたとき，どのような画像が生成されるか確認してください．
