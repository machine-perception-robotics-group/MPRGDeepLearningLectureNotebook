# %% [markdown]
# # 繰り返し処理による異常検知
#
# ---
# ## 目的
# Variational Autoencoder (VAE) を用いた，繰り返し処理による異常検知 [1] の仕組みについて理解する．`vae.ipynb`のVAEと同じ考え方をベースに，より深い畳み込みネットワークと，実データセットに対する異常検知への応用を扱う．
#
# [1] David Dehaene, Oriel Frigo, Sébastien Combrexelle, Pierre Eline, "Iterative energy-based projection on a normal data manifold for anomaly localization," ICLR, 2020.

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートしたのち，GPUを使用した計算が可能かどうかを確認する．

# %%
import os
import zipfile
from time import time
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import gdown

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

# %% [markdown]
# ## MVTec-ADデータセット
# この演習では，[MVTec Anomaly Detection (MVTec-AD) Dataset](https://www.mvtec.com/company/research/datasets/mvtec-ad)を使用します．MVTec-ADは異常検知評価用のデータセットで，さまざまな種類の物体について，正常画像と異常画像が用意されています．今回はこのうち「capsule」のデータを例に異常検知を行います．
#
# ![mvtech_ad](images/mvtech_ad.png)
#
# 以下のセルで，Googleドライブに配置したcapsuleの画像データ（オリジナルの1024×1024 pixelsからファイルサイズ削減のため512×512 pixelsにリサイズ済み）を`gdown`でダウンロードします．解凍すると，`capsule`フォルダの中に学習用データの`train`フォルダと評価用データの`test`フォルダがあり，`test`フォルダの中には欠陥の種類ごとにサブフォルダが分かれています．

# %%
data_root = './anomaly_det_data'
if not os.path.isdir(data_root):
    gdown.download(id='1xSC7x2CelCehA-DJGZSuWFwDpPs8g-4G', output='anomaly_det_data.zip', quiet=False)
    with zipfile.ZipFile('anomaly_det_data.zip') as f:
        f.extractall('./')

# %% [markdown]
# ### データセットクラスの作成
# MVTec-ADの画像を読み込むための`MVTecAD`データセットクラスを定義します．`image_dir`で指定したフォルダ内の連番の画像ファイルを読み込み，`transform`で指定した前処理を適用して返します．
#
# torch.zeros(1)はダミーのラベルです．実際の値としては使われていません．
#
# このノートブックのVAEは教師なし学習（画像を再構成するだけ）なので，本来ラベルは不要です．しかしDataLoaderから取り出す際に，学習・評価ループ側で
#
# ```python
# for inputs, _ in train_loader:
# ```
#
# のように `inputs, _` という2要素のタプルとしてアンパックしている（torchvision.datasets.MNISTなど，他の多くのデータセットクラスが(image, label)を返す慣習に合わせた書き方）ため，`__getitem__`側もそれに合わせて2つの値を返す必要があります．そのための形合わせ用のプレースホルダーとして`torch.zeros(1)`を返しているだけで，ループ内では_として明示的に破棄されており，値自体（0であること）に意味はありません

# %%
class MVTecAD(torch.utils.data.Dataset):
    def __init__(self, image_dir, transform):
        self.transform = transform
        self.image_dir = image_dir

    def __len__(self):
        return len(os.listdir(self.image_dir))

    def __getitem__(self, i):
        filename = '{:0>3}.png'.format(i)
        image = Image.open(os.path.join(self.image_dir, filename))
        if self.transform:
            image = self.transform(image)
        return image, torch.zeros(1)

# %% [markdown]
# ## ネットワークモデル
# VAEのネットワークモデルを定義します．基本的な考え方（Encoder・Decoder・Reparameterization trick）は`vae.ipynb`のVAEと同じですが，本ノートブックでは$128\times128$のカラー画像を扱うため，繰り返し処理による異常検知の論文[1]で使用されている構造にならい，Encoder・Decoderともに8層の畳み込みで構成します．

# %%
class VAE(nn.Module):
    def __init__(self, z_dim=100, input_c=3):
        super().__init__()
        self.z_dim = z_dim

        self.encoder = nn.Sequential(
            nn.Conv2d(input_c, 32, kernel_size=4, stride=2, padding=1),  # 128 -> 64
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(32, 32, kernel_size=4, stride=2, padding=1),  # 64 -> 32
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),  # 32 -> 32
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),  # 32 -> 16
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),  # 16 -> 16
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),  # 16 -> 8
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),  # 8 -> 8
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(64, 32, kernel_size=3, stride=1, padding=1),  # 8 -> 8
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(32, z_dim, kernel_size=8, stride=1),  # 8 -> 1
        )

        self.mu_fc = nn.Linear(z_dim, z_dim)
        self.logvar_fc = nn.Linear(z_dim, z_dim)

        self.decoder = nn.Sequential(
            nn.Upsample(scale_factor=8, mode='nearest'),
            nn.Conv2d(z_dim, 32, kernel_size=3, stride=1, padding=1),  # 1 -> 8
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),  # 8 -> 8
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),  # 8 -> 8
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1),  # 8 -> 16
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),  # 16 -> 16
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.Conv2d(64, 32, kernel_size=3, stride=1, padding=1),  # 16 -> 32
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),  # 32 -> 32
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),  # 32 -> 64
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
            nn.Upsample(scale_factor=2, mode='nearest'),
            nn.Conv2d(32, input_c, kernel_size=3, stride=1, padding=1),  # 64 -> 128
            nn.Sigmoid(),
        )

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        h = torch.flatten(self.encoder(x), start_dim=1)
        mu = self.mu_fc(h)
        logvar = self.logvar_fc(h)
        z = self.reparameterize(mu, logvar)

        x_hat = self.decoder(z.view(z.size(0), -1, 1, 1))
        self.mu = mu.squeeze()
        self.logvar = logvar.squeeze()
        return x_hat

# %% [markdown]
# ## データセット・ネットワークモデル・最適化手法・誤差関数の設定
# 学習データのバリエーションを増やすため，`transform`にランダムなアフィン変換・反転を追加します．誤差関数は通常のVAEと同じ（再構成誤差 + KLダイバージェンス）ものを使用します．

# %%
batch_size = 10

transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ToTensor(),
])
train_data = MVTecAD(image_dir='./anomaly_detection_data/capsule/train/good', transform=transform)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=2)

model = VAE(z_dim=100, input_c=3).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=2e-4, betas=(0.5, 0.999), weight_decay=1e-5)


def loss_function(recon_x, x, mu, logvar):
    reconstruction_loss = F.binary_cross_entropy(recon_x, x, reduction='sum')
    kl_div = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return reconstruction_loss + kl_div

# %% [markdown]
# ## 学習
# 学習は通常のVAEと同様に，画像を再構成するように行います．
#
# ※ **この学習は非常に時間がかかり演習時間内に終えることが難しいため，学習の演算を割愛し，学習済みモデルを用いて異常検知の確認を行います．** ご興味のある方は，講義終了後にご自身で動かしてみてください．1000 epochsで約1時間ほどかかります．

# %%
epoch_num = 1000

model.train()

train_start = time()
for epoch in range(1, epoch_num + 1):
    loss_sum = 0.0
    for inputs, _ in train_loader:
        inputs = inputs.to(device)

        output = model(inputs)
        loss = loss_function(output, inputs, model.mu, model.logvar)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_sum += loss.item()

    if epoch % 50 == 0:
        print(f'epoch: {epoch}, loss: {loss_sum / len(train_loader):.4f}, elapsed time: {time() - train_start}')

    if epoch % 100 == 0:
        torch.save(model.state_dict(), 'anomaly_det_model_%04d.pt' % epoch)

# %% [markdown]
# ## VAEによる画像の再構成結果の確認
# 異常検知を行う前に，学習済みモデルを用いて画像が正しく再構成できているかを確認します．結果は左から，入力画像，VAEの出力画像，2つの画像の差分（絶対値）です．ボケた画像が生成されますが，ある程度正しい形状や色を保った画像が出力されていることがわかります．また，大きな割れ目のある部分は差分が大きくなっていることがわかります．

# %%
model.load_state_dict(torch.load('./anomaly_det_data/anomaly_det_model_1000.pt', map_location=device))

transform_test = transforms.Compose([transforms.Resize((128, 128)), transforms.ToTensor()])
test_bad_data = MVTecAD(image_dir='./anomaly_detection_data/capsule/test/crack', transform=transform_test)
test_loader = torch.utils.data.DataLoader(test_bad_data, batch_size=1, shuffle=False)

model.eval()
with torch.no_grad():
    for ind, (inputs, _) in enumerate(test_loader):
        inputs = inputs.to(device)
        reconstructed = model(inputs)

        b = inputs.cpu().numpy()[0].transpose(1, 2, 0)
        a = reconstructed.cpu().numpy()[0].transpose(1, 2, 0)
        diff = np.abs(a - b)

        plt.figure(figsize=(12, 4))
        plt.subplot(1, 3, 1); plt.imshow(b, vmin=0, vmax=1, interpolation='none'); plt.title('input')
        plt.subplot(1, 3, 2); plt.imshow(a, vmin=0, vmax=1, interpolation='none'); plt.title('reconstruction')
        plt.subplot(1, 3, 3); plt.imshow(diff, interpolation='none'); plt.title('diff')
        plt.show()

        if ind == 2:
            break

# %% [markdown]
# ## 繰り返しによる異常検知
# このVAEを用いて，繰り返し処理による異常検知を行います．処理の流れは次の通りです．
#
# 1. 1枚の画像$x_t$を用意する（初回は入力画像そのもの）．
# 2. $x_t$をVAEへ入力し，出力画像との差（MSE）$E(x_t) = (x_t - f_{VAE}(x_t))^2 + \lambda \cdot \| x_t - x_0 \|_1 $を計算する．
# 3. 誤差$E(x_t)$を入力$x_t$について微分した勾配$\nabla E(x_t)$を用いて，$x_{t+1} = x_t - \alpha \nabla E(x_t) \cdot (x_t - f_{VAE}(x_t))^2$により新たな画像$x_{t+1}$を生成する．
# 4. 2〜3を繰り返す．
#
# これを繰り返すことで，異常部分が徐々に正常な状態へ再構成されていきます．
#
# ![anomaly_det](images/anomaly_det.png)

# %%
max_iter = 99
alpha = 0.5
lam = 0.05
th = 0.5

transform_test = transforms.Compose([transforms.Resize((128, 128)), transforms.ToTensor()])
test_bad_data = MVTecAD(image_dir='./anomaly_detection_data/capsule/test/crack', transform=transform_test)
test_bad_loader = torch.utils.data.DataLoader(test_bad_data, batch_size=1, shuffle=False)

model.eval()
mse_loss = nn.MSELoss(reduction='sum').to(device)

for index, (x_org, _) in enumerate(test_bad_loader):
    if index == 0: continue  # 2つ目のサンプルを例として実行するため，1つ目を飛ばす

    img = x_org[0].numpy()
    x_t_images, grad_images, reconstructed_images = [], [], []

    x_org = x_org.to(device).requires_grad_(True)
    with torch.no_grad():
        rec_x = model(x_org)

    loss = mse_loss(x_org, rec_x)  # 初回は $\lambda \cdot \| x_t - x_0 \|_1$ はなし
    loss.backward()
    grads = x_org.grad.data
    x_t = x_org - alpha * grads * (x_org - rec_x) ** 2

    grad_images.append(grads[0].cpu().numpy().transpose(1, 2, 0))
    reconstructed_images.append(rec_x[0].detach().cpu().numpy().transpose(1, 2, 0))
    x_t_images.append(x_t[0].detach().cpu().numpy().transpose(1, 2, 0))

    for i in range(max_iter):
        x_t = x_t.detach().clamp(min=0, max=1).requires_grad_(True)
        with torch.no_grad():
            rec_x = model(x_t)
        rec_loss = mse_loss(x_t, rec_x)

        if rec_loss <= th:
            break

        l1 = torch.abs(x_t - x_org).sum()
        loss = rec_loss + lam * l1
        loss.backward()
        grads = x_t.grad.data

        energy = grads * (x_t - rec_x) ** 2
        x_t = x_t - alpha * energy

        grad_images.append(grads[0].cpu().numpy().transpose(1, 2, 0))
        reconstructed_images.append(rec_x[0].detach().cpu().numpy().transpose(1, 2, 0))
        x_t_images.append(x_t[0].detach().cpu().numpy().transpose(1, 2, 0))

    break  # 1サンプル分の処理が終わった時点でループを抜ける

# %% [markdown]
# ### 結果の表示
# オリジナルの入力画像と，繰り返し処理で得られた画像$x_t$を可視化します．繰り返し処理を行うことで，欠陥部分が徐々に復元され，正常な画像へと近づいていくことがわかります．

# %%
plt.imshow(img.transpose(1, 2, 0), vmin=0, vmax=1, interpolation='none')
plt.title('orig image')
plt.show()

plt.figure(figsize=(30, 30))
for i, x_t_img in enumerate(x_t_images):
    plt.subplot(10, 10, i + 1)
    plt.imshow(x_t_img, vmin=0, vmax=1, interpolation='none')
plt.show()

# %% [markdown]
# ### 類似度（SSIM）による欠陥領域の可視化
# 入力画像と，繰り返し処理で得られた画像の類似度の差から，欠陥領域の特定を行います．類似度の指標として，Structural Similarity (SSIM) とその逆であるStructural Dissimilarity (DSSIM, `1 - SSIM`) を使用します．元画像`input_image`と，n回目の反復で得られた画像`n_iter_image`の間でSSIMを計算し（`scikit-image`の関数を使用），画像全体の類似度`ssim_value`と，微小領域（パッチ）ごとの類似度`ssim_img`を求めます．DSSIMを可視化すると，欠陥領域で高い値になっていることが確認できます．

# %%
from skimage.metrics import structural_similarity as ssim

iter_index = 99  # 何回目の反復画像と比較するか

input_image = np.mean(img.transpose(1, 2, 0), axis=2)
n_iter_image = np.mean(x_t_images[iter_index], axis=2)

ssim_value, ssim_img = ssim(input_image, n_iter_image, win_size=5, full=True, data_range=1.0)
dssim_img = 1. - ssim_img

plt.figure(figsize=(10, 3))
plt.subplot(1, 3, 1); plt.imshow(input_image, cmap='gray', vmin=0, vmax=1, interpolation='none'); plt.title('input')
plt.subplot(1, 3, 2); plt.imshow(n_iter_image, cmap='gray', vmin=0, vmax=1, interpolation='none'); plt.title(f'iter={iter_index}')
plt.subplot(1, 3, 3); plt.imshow(dssim_img, vmin=0, vmax=1, interpolation='none'); plt.title('DSSIM'); plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 課題
#
# 1. その他の画像（正常画像や他の種類の異常画像）に対する結果を確認してください．
# 2. 反復回数を増加させたとき，再構成画像がどのように変化するか確認してください．
