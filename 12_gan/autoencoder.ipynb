# %% [markdown]
# # Auto Encoder（AE）による画像の再構成
#
# ---
# ## 目的
# Auto Encoder (AE) を用いて，画像を低次元の潜在変数へ圧縮し，そこから元の画像を復元する仕組みを理解する．MNISTデータセットを用いてAEを学習し，再構成結果と，学習で獲得した潜在空間を可視化して確認する．

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートしたのち，GPUを使用した計算が可能かどうかを確認する．

# %%
import numpy as np
from time import time
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

# %% [markdown]
# ## データセットの読み込み
# MNISTデータセットを読み込みます．AEは，入力画像そのものを教師信号として用いる**自己教師あり学習**（教師なしでラベルを使わず，入力データ自身から学習信号を作る学習方法）で学習します．そのため，`DataLoader`が返すラベル（`0〜9`の数字ラベル）は使用しません．

# %%
train_data = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
test_data = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor(), download=True)

print(len(train_data), len(test_data))

# %% [markdown]
# ## ネットワークモデルの定義
# AEは，画像を潜在変数（低次元のベクトル）に圧縮する**Encoder**と，潜在変数から画像を復元する**Decoder**から構成されます．本ノートブックでは，Encoder・Decoderともに全結合層3層で構成し，`784 → 256 → 100 → 潜在変数の次元数`（Encoder）とその逆順（Decoder）という対称な構造にします．
#
# Decoderの最終層には，出力する画素値を入力画像と同じ[0, 1]の範囲に収めるため，Sigmoid関数を適用します．

# %%
class AutoEncoder(nn.Module):
    def __init__(self, n_hidden):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(28 * 28, 256), nn.ReLU(inplace=True),
            nn.Linear(256, 100), nn.ReLU(inplace=True),
            nn.Linear(100, n_hidden),
        )
        self.decoder = nn.Sequential(
            nn.Linear(n_hidden, 100), nn.ReLU(inplace=True),
            nn.Linear(100, 256), nn.ReLU(inplace=True),
            nn.Linear(256, 28 * 28), nn.Sigmoid(),
        )

    def forward(self, x):
        h = self.encoder(x)
        return self.decoder(h)

# %% [markdown]
# ## ネットワークの作成
# 入力層のサイズ（`28*28`）と潜在変数の次元数（`hidden_num`）を指定してAEを作成します．最適化手法にはAdamを使用します．潜在変数の次元数は，後ほど潜在空間を可視化するために`2`とします．

# %%
hidden_num = 2

model = AutoEncoder(n_hidden=hidden_num).to(device)
optimizer = torch.optim.Adam(model.parameters())

# %% [markdown]
# ## 学習
# ミニバッチサイズを100，学習エポック数を20として学習します．AEは連続値（画素値）を出力する回帰問題として扱うため，誤差関数には`MSELoss`を使用します．入力画像`image`をそのまま教師信号として用い，`model(image)`が`image`自身に近づくように学習します．

# %%
batch_size = 100
epoch_num = 20

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=2)
criterion = nn.MSELoss().to(device)

model.train()
start = time()
for epoch in range(1, epoch_num + 1):
    sum_loss = 0.0

    for image, _ in train_loader:
        image = image.view(image.size(0), -1).to(device)

        y = model(image)
        loss = criterion(y, image)

        model.zero_grad()
        loss.backward()
        optimizer.step()

        sum_loss += loss.item()

    print(f'epoch: {epoch}, mean loss: {sum_loss / len(train_loader):.4f}, elapsed_time: {time() - start:.4f}')

# %% [markdown]
# ## テスト
# 学習したネットワークを用いて画像を再構成し，結果を可視化します．

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False)

model.eval()
test_result, test_gt = [], []
with torch.no_grad():
    for count, (image, _) in enumerate(test_loader):
        image = image.view(image.size(0), -1).to(device)

        y = model(image)

        test_result.append(y.cpu())
        test_gt.append(image.cpu())

        if count == 9:
            break

cols = 10
fig, axes = plt.subplots(2, cols, figsize=(14, 2.8))
for c in range(cols):
    axes[0, c].imshow(test_gt[c].reshape(28, 28), cmap='gray'); axes[0, c].axis('off')
    axes[1, c].imshow(test_result[c].reshape(28, 28), cmap='gray'); axes[1, c].axis('off')
fig.suptitle('input (top) / reconstruction (bottom)')
plt.show()

# %% [markdown]
# ## 潜在空間の可視化
# 潜在空間の2次元ベクトルを格子状に作成し，Decoderへ入力して画像を生成することで，AEが獲得した潜在空間を可視化します．
#
# ※ この処理は`hidden_num = 2`の場合のみ動作します．

# %%
nv = 25
value2 = np.linspace(-2.0, 2.0, nv)
value1 = np.linspace(-2.0, 2.0, nv)

plot_array = np.zeros([28 * nv, 28 * nv], dtype=np.float32)
model.eval()
with torch.no_grad():
    for i, yi in enumerate(value1):
        for j, xj in enumerate(value2):
            xx = torch.tensor([[yi, xj]], dtype=torch.float32).to(device)
            output = model.decoder(xx)
            output = output.view(28, 28).cpu().numpy()
            plot_array[(nv - i - 1) * 28:(nv - i) * 28, j * 28:(j + 1) * 28] = output

plt.figure(figsize=(10, 10))
plt.imshow(plot_array, origin='upper', cmap='gray')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 課題
#
# 1. 潜在変数の次元数（`hidden_num`）やEncoder・Decoderの層数を変更し，再構成の性能がどのように変化するか比較してください（Encoder・Decoderのユニット数・層数は，対称になるように設計してください）．
# 2. 学習済みのAEに，学習時には見せていない画像（例えば手書きでない図形やランダムノイズ画像）を入力すると，どのような画像が出力されるか確認してください．
# 3. `denoising_autoencoder.ipynb`で学習するDenoising AEに，本ノートブックのAE（ノイズを学習していないモデル）で同じノイズ画像を復元させるとどうなるか比較してください．
