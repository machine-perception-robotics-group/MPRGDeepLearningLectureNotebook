# %% [markdown]
# <a href="https://colab.research.google.com/github/machine-perception-robotics-group/MPRGDeepLearningLectureNotebook/blob/master/12_gan/05_CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CycleGAN
# ## 目的
# Cycle GANのネットワークを構築して動作を理解する．

# %% [markdown]
# # データセット
# りんごとオレンジが含まれるデータセットのzipファイルをダウンロードして，解凍します．
# もし違うデータを使いたい場合は，以下のURLから選択してURL先のデータをwgetで取得してください．<br>
# https://people.eecs.berkeley.edu/~taesung_park/CycleGAN/datasets/

# %%
# !wget -q https://www.dropbox.com/s/on1jla0d3ghjmff/apple2orange.zip?dl=0 -O apple2orange.zip
# !unzip -q -o apple2orange.zip

# %% [markdown]
# # 各種モジュールのインポート

# %%
import os
import random
import itertools
import numpy as np
from PIL import Image
# %matplotlib inline
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %% [markdown]
# # ネットワークの構築
# CycleGANは，「画像を入力→異なるスタイルへ変換→変換したものを元のスタイルへ戻す」という処理によって，対になる画像がない場合であってもスタイルを変換できる代物です．<br>
# 以下に示す図は，CycleGANによる変換及び再構成を表しています．

# %% [markdown]
# <img src="https://www.dropbox.com/s/7339ohcadohs6o7/Cyclegan.png?dl=1" width=40%>

# %% [markdown]
# CycleGANが提案される前は，pix2pixと呼ばれるペア画像を必要とするスタイル変換が主流でした．
# ペア画像とは，例えばRGB画像とその画像に対するセグメンテーション画像のことを指します．<br>
#
# CycleGANのGeneratorはResidual networkをベースに設計します．
# Residual network (ResNet)は，残差機構を用いることで多層になった場合でも特徴を残すことが可能なネットワークです．
# ResBlockは，カーネルサイズ3×3，ストライド1，パディング1の2層の畳み込み層で構築します．
# 以下にResBlockの図を示します．

# %% [markdown]
# <img src="https://www.dropbox.com/s/pow1wsxhc37gmts/ResBlock.png?dl=1" width=50%>
#
# ここで$f(x)$は，前層が出力した特徴マップを表しています．
# また$g(x)$は，残差を加算した特徴マップです．

# %%
class ResBlock(nn.Module):
    def __init__(self, features):
        super(ResBlock, self).__init__()
        block_list = []
        self.block = self.make_block(block_list, features)
        
    def make_block(self, modules_list, features):
        modules_list.append(nn.Conv2d(features, features, kernel_size=3, stride=1, padding=1, bias=False))
        modules_list.append(self.select_normalization(norm='instance', features=features))
        modules_list.append(nn.ReLU(inplace=True))
        modules_list.append(nn.Conv2d(features, features, kernel_size=3, stride=1, padding=1, bias=False))
        modules_list.append(self.select_normalization(norm='instance', features=features))
        modules = nn.Sequential(*modules_list)
        return modules
        
    def select_normalization(self, norm, features):
        if norm == 'batch':
            return nn.BatchNorm2d(features)
        elif norm == 'instance':
            return nn.InstanceNorm2d(features)
        else:
            assert 0, '%s is not supported.' % norm

    def forward(self, x):
        out = x + self.block(x)
        return out

# %% [markdown]
# CycleGANのGeneratorは，入力に潜在変数ではなく変換元となる画像を入力して，画像を出力します．そのため，GeneratorはEncoder-Decoder構造をしています．Encoderは，入力画像を表現するために有益な情報を残した特徴抽出をします．一方で，DecoderはEncoderがエンコードした特徴を用いて画像の変換をします．このときにEncoderとDecoderの間には，任意の数積み上げたResBlockを使用することで，さらに特徴を凝縮します．
# ここで，ResBlockは，残差を用いてネットワークを構築するResidual Networksで使用されているものです．

# %% [markdown]
# <img src="https://www.dropbox.com/s/yha9im0bbb6p0t1/CycleGAN_G.png?dl=1" width=50%>

# %%
class Generator(nn.Module):
    def __init__(self, n_down, n_up, n_res, in_features):
        super(Generator, self).__init__()
        
        out_features = 16
        first_conv = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(in_features, out_features, kernel_size=7, stride=1, padding=0, bias=False),
            self.select_normalization(norm='instance', features=out_features),
            nn.ReLU(inplace=True)]
        
        down_block = []
        for _ in range(n_down):
            in_features = out_features
            out_features = in_features * 2
            down_block += [
                nn.Conv2d(in_features, out_features, kernel_size=3, stride=2, padding=1, bias=False),
                self.select_normalization(norm='instance', features=out_features),
                nn.ReLU(inplace=True)]
            
        res_block = []
        res_features = out_features
        for _ in range(n_res):
            res_block.append(ResBlock(res_features))
            
        up_block = []
        in_features = res_features
        out_features = in_features // 2
        for _ in range(n_up):
            up_block += [
                nn.ConvTranspose2d(in_features, out_features, kernel_size=3, stride=2, padding=1, output_padding=1, bias=False),
                self.select_normalization(norm='instance', features=out_features),
                nn.ReLU(inplace=True)]
            in_features = out_features
            out_features = in_features // 2
            
        #up_block += [
        #    nn.ConvTranspose2d(in_features, out_features, kernel_size=3, stride=2, padding=1, output_padding=1, bias=False),
        #    self.select_normalization(norm='instance', features=out_features),
        #    nn.Tanh()]
        
        last_conv = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(in_features, 3, kernel_size=7, stride=1, padding=0, bias=True),
            nn.Tanh()]
        
        self.first_conv = nn.Sequential(*first_conv)
        self.down_block = nn.Sequential(*down_block)
        self.res_block = nn.Sequential(*res_block)
        self.up_block = nn.Sequential(*up_block)
        self.last_conv = nn.Sequential(*last_conv)
    
    def select_normalization(self, norm, features):
        if norm == 'batch':
            return nn.BatchNorm2d(features)
        elif norm == 'instance':
            return nn.InstanceNorm2d(features)
        else:
            assert 0, '%s is not supported.' % norm
            
    def forward(self, x):
        h = self.first_conv(x)
        h = self.down_block(h)
        h = self.res_block(h)
        h = self.up_block(h)
        out = self.last_conv(h)   
        return out

# %% [markdown]
# Discriminatorは，実画像であるかGeneratorによって変換された画像であるかの分類をするため，通常のGANと同じ振る舞いです．
# DC-GANは，画像1枚を入力して実画像であるか生成画像であるかを判定しています．
# つまり，Dicriminatorは画像全体を見て判断していると言っても良いでしょう．<br>
# ところが，CycleGANはPatchGANをベースにDiscriminatorを構築しているので，少し変わった方法で実画像か生成画像かの判定をしています．
# PatchGANは，画像全体ではなく画像をいくつかのパッチに区切って入力することで，局所領域ごとに実画像なのか生成画像なのかを判定します．
# これによって，画像全体で判定するよりも性能がよくなることが知られています．
# 以下に通常のDiscriminatorとCycleGANのDsicriminatorを示します．

# %% [markdown]
# <img src="https://www.dropbox.com/s/yrud8444g26g0yz/CycleGAN_D.png?dl=1" width=50%>

# %% [markdown]
# 図にも示したように，厳密には任意の数のPatchに分割することは手間なので，Discriminator内部の畳み込み処理のカーネルサイズによって受容野の広さを制御して，出力値をスカラー値ではなく特徴マップとすることによってPatchに分割したときと同様の処理を実現しています．

# %%
class Discriminator(nn.Module):
    def __init__(self, n_layers=3):
        super(Discriminator, self).__init__()
        out_features = 32
        modules = [nn.Conv2d(3, out_features, kernel_size=4, stride=2, padding=1, bias=True),
                   nn.LeakyReLU(negative_slope=0.2, inplace=True)]

        for _ in range(n_layers):
            in_features = out_features
            out_features = in_features * 2
            modules += [nn.Conv2d(in_features, out_features, kernel_size=4, stride=2, padding=1, bias=False),
                        self.select_normalization(norm='instance', features=out_features),
                        nn.LeakyReLU(negative_slope=0.2, inplace=True)]
        
        modules += [nn.Conv2d(out_features, 1, kernel_size=4, stride=1, padding=1, bias=True)]
        self.layers = nn.Sequential(*modules)
    
    def select_normalization(self, norm, features):
        if norm == 'batch':
            return nn.BatchNorm2d(features)
        elif norm == 'instance':
            return nn.InstanceNorm2d(features)
        else:
            assert 0, '%s is not supported.' % norm
            
    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# # DataLoaderの定義
# pytorchに含まれているデータ以外のデータセットを用いて学習するときや特殊なデータ構造を利用して学習をする時は，DataLoaderを自分で定義する必要があります．今回使用するデータセットは，zipファイルを解凍すると，内部にtrainA，trainB，testA，testBという名前のディレクトリが含まれています．
# また，それぞれのディレクトリの中に画像が入っています．
#
# これらを考慮して以下に示すようにDataLoaderを定義します．
#
# datapath：zipファイルを解凍したときにできるディレクトリのパス

# %%
class CycleGAN_Dataset(torch.utils.data.Dataset):
    def __init__(self, datapath, transforms=None):
        self.transforms = transforms
        self.A_path = os.path.join(datapath, 'trainA')
        self.B_path = os.path.join(datapath, 'trainB')
        dataA_list = os.listdir(self.A_path)
        dataB_list = os.listdir(self.B_path)
        random.shuffle(dataA_list)
        random.shuffle(dataB_list)
        self.datalength = min(len(dataA_list), len(dataB_list))
        self.dataA = dataA_list[:self.datalength]
        self.dataB = dataB_list[:self.datalength]
        
    def __len__(self):
        return self.datalength
    
    def __getitem__(self, i):
        imgA = Image.open(os.path.join(self.A_path, self.dataA[i]))
        imgB = Image.open(os.path.join(self.B_path, self.dataB[i]))
        
        if self.transforms:
            imgA = self.transforms(imgA)
            imgB = self.transforms(imgB)
        
        return imgA, imgB

# %% [markdown]
# # Image History Buffer
# CycleGANでは，任意のサイズのBufferを定義します．
# これにより，過去にDiscriminatorをうまく騙せた画像に依存して変換のバリエーションが少なくなる問題を回避することができます．
#
# Image Bufferは，Generatorが変換した画像を溜め込みますが，任意のiteration数で中身の画像を最新の画像にアップデートします．このときに，全ての画像を破棄して新しいものへアップデートするのではなく，一部のみをアップデートします．つまり，異なるiteration数で変換した画像が混在したBufferとなっています．

# %%
class Image_History_Buffer:
    def __init__(self, pool_size):
        self.pool_size = pool_size
        if self.pool_size > 0:  # create an empty pool
            self.num_imgs = 0
            self.images = []
        
    def query(self, images):
        if self.pool_size == 0:  # if the buffer size is 0, do nothing
            return images
        return_images = []
        for image in images:
            image = torch.unsqueeze(image.data, 0)
            if self.num_imgs < self.pool_size:   # if the buffer is not full; keep inserting current images to the buffer
                self.num_imgs = self.num_imgs + 1
                self.images.append(image)
                return_images.append(image)
            else:
                p = random.uniform(0, 1)
                if p > 0.5:  # by 50% chance, the buffer will return a previously stored image, and insert the current image into the buffer
                    random_id = random.randint(0, self.pool_size - 1)  # randint is inclusive
                    tmp = self.images[random_id].clone()
                    self.images[random_id] = image
                    return_images.append(tmp)
                else:       # by another 50% chance, the buffer will return the current image
                    return_images.append(image)
        return_images = torch.cat(return_images, 0)   # collect all the images and return
        return return_images

# %%
def get_lambda_rule(start_epoch, decay_epoch, epochs):
    def lambda_rule(epoch):
        return 1.0 - max(0, epoch + start_epoch - decay_epoch) / float(epochs - decay_epoch)
    return lambda_rule

# %% [markdown]
# # ネットワークの作成，学習に必要なパラメータの定義
# CycleGANは，ドメインAからBに変換するGeneratorとその逆の処理をするGeneratorの2つ作成する必要があります．また，Discriminatorも同様で，ドメインAのためのDiscriminator，ドメインBのためのDicriminatorも作成します．

# %%
lr = 2e-4
img_size = 256
max_size = 12800
betas = (0.5, 0.999)
batchsize = 1
imgsize = 256
n_epochs = 10
pool_size = 100
datapath = 'apple2orange'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
transform = transforms.Compose([transforms.Resize(img_size, Image.BICUBIC),
                                transforms.RandomHorizontalFlip(),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))])
train_data = CycleGAN_Dataset(datapath=datapath, transforms=transform)
training_dataset = DataLoader(train_data, batch_size=batchsize, shuffle=True , drop_last=True)
G_A2B = Generator(n_down=5, n_up=5, n_res=9, in_features=3).to(device)
G_B2A = Generator(n_down=5, n_up=5, n_res=9, in_features=3).to(device)
D_A = Discriminator(n_layers=3).to(device)
D_B = Discriminator(n_layers=3).to(device)
g_opt = optim.Adam(itertools.chain(G_A2B.parameters(), G_B2A.parameters()), lr=lr, betas=betas)
d_A_opt = optim.Adam(D_A.parameters(), lr=lr, betas=betas)
d_B_opt = optim.Adam(D_B.parameters(), lr=lr, betas=betas)
l1_norm = nn.L1Loss()
criterion_idn = nn.L1Loss()
LambdaLR = get_lambda_rule(start_epoch=0, decay_epoch=100, epochs=n_epochs)
g_lr_scheduler = torch.optim.lr_scheduler.LambdaLR(g_opt, lr_lambda=LambdaLR)
d_a_lr_scheduler = torch.optim.lr_scheduler.LambdaLR(d_A_opt, lr_lambda=LambdaLR)
d_b_lr_scheduler = torch.optim.lr_scheduler.LambdaLR(d_B_opt, lr_lambda=LambdaLR)
buffer_for_fakeA = Image_History_Buffer(pool_size=pool_size)
buffer_for_fakeB = Image_History_Buffer(pool_size=pool_size)

# %% [markdown]
# # CycleGANの学習
# これまでに定義したネットワークを用いて学習します．
#
# CycleGANの誤差関数は，オリジナルのGANとは異なるものが使用されています．
# * Real/Fakeの誤差関数：GANを学習するために必要な誤差関数です．LS-GANで提案されているカイ2乗誤差を誤差関数とする方法を利用しています．
# $$\mathcal{L}_{adv}^{A} = \mathbb{E}\left[\left(D_{A}(x_{A}) - 1\right)^{2}\right] + \mathbb{E}\left[D_{A}\left(G_{B\rightarrow A}(x_{B})\right)^{2}\right]$$
# $$\mathcal{L}_{adv}^{B} = \mathbb{E}\left[\left(D_{B}(x_{B}) - 1\right)^{2}\right] + \mathbb{E}\left[D_{B}\left(G_{A\rightarrow B}(x_{A})\right)^{2}\right]$$
# * Cycle consistency loss：オリジナルの画像と再構成した画像の一貫性を保つために必要な誤差関数です．
# $$
# \mathcal{L}_{cycle}^{A} = \|x_{A} - G_{B\rightarrow A}\left(G_{A\rightarrow B}\left(x_{A}\right)\right)\|_{1}
# $$
# $$
# \mathcal{L}_{cycle}^{B} = \|x_{B} - G_{A\rightarrow B}\left(G_{B\rightarrow A}\left(x_{B}\right)\right)\|_{1}
# $$
# * Identity loss：別のスタイルへ変換したときにオリジナル画像を大幅に変更してしまうことを抑制するために必要な誤差です．実際，この誤差を抜いても学習は可能で，スタイルの変換もすることはできます．この誤差関数が最大の効果を発揮する場面は，ある風景画を絵画風に変換するときです．
# $$
# \mathcal{L}_{identity}^{A} = \|x_{A} - G_{A\rightarrow B}\left(x_{A}\right)\|_{1}
# $$
# $$
# \mathcal{L}_{identity}^{B} = \|x_{B} - G_{B\rightarrow A}\left(x_{B}\right)\|_{1}
# $$

# %%
for epoch in range(1, n_epochs+1):
    for idx, (imgA, imgB) in enumerate(training_dataset):
        lambda_val = 10
        lambda_id_val = 0.5 * lambda_val
        imgA, imgB = imgA.cuda(), imgB.cuda()
        
        # Update the discriminator (D_A, D_B)
        D_A.zero_grad()
        D_B.zero_grad()
        disA_out_real = D_A(imgA)
        disB_out_real = D_B(imgB)

        imgB_fake = G_A2B(imgA)
        imgB_fake = buffer_for_fakeB.query(imgB_fake)
        disB_out_fake = D_B(imgB_fake.detach())
        
        imgA_fake = G_B2A(imgB)
        imgA_fake = buffer_for_fakeA.query(imgA_fake)
        disA_out_fake = D_A(imgA_fake.detach())
        disA_loss = 0.5 * (((disA_out_real - 1) ** 2).mean() + (disA_out_fake ** 2).mean())
        disB_loss = 0.5 * (((disB_out_fake - 1) ** 2).mean() + (disB_out_fake ** 2).mean())
        disA_loss.backward()
        disB_loss.backward()
        d_A_opt.step()
        d_B_opt.step()
        
        # Update the generator (G)
        G_B2A.zero_grad()
        G_A2B.zero_grad()
        disB_out_fake = D_B(imgB_fake)
        disA_out_fake = D_A(imgA_fake)
        gen_adv_loss = 0.5 * (((disB_out_fake - 1) ** 2).mean() + ((disA_out_fake - 1) ** 2).mean())
        
        imgA_rec = G_B2A(imgB_fake)
        imgB_rec = G_A2B(imgA_fake)
        cycle_consistency_loss = 0.5 * (l1_norm(imgA_rec, imgA) + l1_norm(imgB_rec, imgB))
        identity_loss = 0.5 * (criterion_idn(G_B2A(imgB_fake), imgA) + criterion_idn(G_A2B(imgA_fake), imgB))
        gen_loss = gen_adv_loss + lambda_val * cycle_consistency_loss + lambda_id_val * identity_loss
        gen_loss.backward()
        g_opt.step()
        
        if idx % 100 == 0:
            print('Training epoch: {} [{}/{} ({:.0f}%)] | D loss (A): {:.6f} | D loss (B): {:.6f} | G loss: {:.6f} | Consistency: {:.6f} | Identity: {:.6f} |'\
                  .format(epoch, idx * len(imgA), len(training_dataset.dataset),
                  100. * idx / len(training_dataset), disA_loss.item(), disB_loss.item(), gen_loss.item(), cycle_consistency_loss.item(), identity_loss.item()))
# Out:
# Training epoch: 1 [0/995 (0%)] | D loss (A): 0.437663 | D loss (B): 0.674687 | G loss: 11.756495 | Consistency: 0.757436 | Identity: 0.757436 |
# Training epoch: 1 [100/995 (10%)] | D loss (A): 0.062702 | D loss (B): 0.265966 | G loss: 7.253510 | Consistency: 0.440926 | Identity: 0.440926 |
# Training epoch: 1 [200/995 (20%)] | D loss (A): 0.030655 | D loss (B): 0.267046 | G loss: 6.726613 | Consistency: 0.406833 | Identity: 0.406833 |
# Training epoch: 1 [300/995 (30%)] | D loss (A): 0.008233 | D loss (B): 0.252266 | G loss: 8.831206 | Consistency: 0.543829 | Identity: 0.543829 |
# Training epoch: 1 [400/995 (40%)] | D loss (A): 0.004676 | D loss (B): 0.318139 | G loss: 8.079090 | Consistency: 0.497600 | Identity: 0.497600 |
# Training epoch: 1 [500/995 (50%)] | D loss (A): 0.008873 | D loss (B): 0.255873 | G loss: 7.964970 | Consistency: 0.483224 | Identity: 0.483224 |
# Training epoch: 1 [600/995 (60%)] | D loss (A): 0.008779 | D loss (B): 0.253591 | G loss: 10.550163 | Consistency: 0.657932 | Identity: 0.657932 |
# Training epoch: 1 [700/995 (70%)] | D loss (A): 0.004591 | D loss (B): 0.254362 | G loss: 9.330728 | Consistency: 0.584369 | Identity: 0.584369 |
# Training epoch: 1 [800/995 (80%)] | D loss (A): 0.038073 | D loss (B): 0.253800 | G loss: 6.102339 | Consistency: 0.364839 | Identity: 0.364839 |
# Training epoch: 1 [900/995 (90%)] | D loss (A): 0.008614 | D loss (B): 0.251318 | G loss: 10.298772 | Consistency: 0.646446 | Identity: 0.646446 |
# Training epoch: 2 [0/995 (0%)] | D loss (A): 0.013119 | D loss (B): 0.251504 | G loss: 9.487961 | Consistency: 0.588019 | Identity: 0.588019 |
# Training epoch: 2 [100/995 (10%)] | D loss (A): 0.002593 | D loss (B): 0.254499 | G loss: 7.695502 | Consistency: 0.471230 | Identity: 0.471230 |
# Training epoch: 2 [200/995 (20%)] | D loss (A): 0.002178 | D loss (B): 0.250313 | G loss: 7.196770 | Consistency: 0.438709 | Identity: 0.438709 |
# Training epoch: 2 [300/995 (30%)] | D loss (A): 0.004598 | D loss (B): 0.252184 | G loss: 7.043983 | Consistency: 0.427718 | Identity: 0.427718 |
# Training epoch: 2 [400/995 (40%)] | D loss (A): 0.003695 | D loss (B): 0.251173 | G loss: 7.644125 | Consistency: 0.468174 | Identity: 0.468174 |
# Training epoch: 2 [500/995 (50%)] | D loss (A): 0.003097 | D loss (B): 0.251229 | G loss: 5.716446 | Consistency: 0.336456 | Identity: 0.336456 |
# Training epoch: 2 [600/995 (60%)] | D loss (A): 0.010086 | D loss (B): 0.253611 | G loss: 9.585688 | Consistency: 0.599268 | Identity: 0.599268 |
# Training epoch: 2 [700/995 (70%)] | D loss (A): 0.027729 | D loss (B): 0.254528 | G loss: 8.084646 | Consistency: 0.495070 | Identity: 0.495070 |
# Training epoch: 2 [800/995 (80%)] | D loss (A): 0.013246 | D loss (B): 0.261155 | G loss: 9.501034 | Consistency: 0.591021 | Identity: 0.591021 |
# Training epoch: 2 [900/995 (90%)] | D loss (A): 0.003996 | D loss (B): 0.255446 | G loss: 6.388388 | Consistency: 0.382142 | Identity: 0.382142 |
# Training epoch: 3 [0/995 (0%)] | D loss (A): 0.002840 | D loss (B): 0.250374 | G loss: 6.717063 | Consistency: 0.404347 | Identity: 0.404347 |
# Training epoch: 3 [100/995 (10%)] | D loss (A): 0.004010 | D loss (B): 0.250997 | G loss: 11.153333 | Consistency: 0.702254 | Identity: 0.702254 |
# Training epoch: 3 [200/995 (20%)] | D loss (A): 0.007802 | D loss (B): 0.250868 | G loss: 6.017228 | Consistency: 0.360984 | Identity: 0.360984 |
# Training epoch: 3 [300/995 (30%)] | D loss (A): 0.007422 | D loss (B): 0.251089 | G loss: 9.331189 | Consistency: 0.580059 | Identity: 0.580059 |
# Training epoch: 3 [400/995 (40%)] | D loss (A): 0.002671 | D loss (B): 0.250245 | G loss: 7.825299 | Consistency: 0.478896 | Identity: 0.478896 |
# Training epoch: 3 [500/995 (50%)] | D loss (A): 0.001852 | D loss (B): 0.255001 | G loss: 10.628289 | Consistency: 0.666262 | Identity: 0.666262 |
# Training epoch: 3 [600/995 (60%)] | D loss (A): 0.002513 | D loss (B): 0.250846 | G loss: 6.870632 | Consistency: 0.419706 | Identity: 0.419706 |
# Training epoch: 3 [700/995 (70%)] | D loss (A): 0.003244 | D loss (B): 0.250164 | G loss: 7.397868 | Consistency: 0.451177 | Identity: 0.451177 |
# Training epoch: 3 [800/995 (80%)] | D loss (A): 0.001264 | D loss (B): 0.250261 | G loss: 9.536446 | Consistency: 0.593997 | Identity: 0.593997 |
# Training epoch: 3 [900/995 (90%)] | D loss (A): 0.005741 | D loss (B): 0.250383 | G loss: 6.367147 | Consistency: 0.382000 | Identity: 0.382000 |
# Training epoch: 4 [0/995 (0%)] | D loss (A): 0.003168 | D loss (B): 0.250669 | G loss: 7.061206 | Consistency: 0.427792 | Identity: 0.427792 |
# Training epoch: 4 [100/995 (10%)] | D loss (A): 0.014493 | D loss (B): 0.250422 | G loss: 6.832870 | Consistency: 0.418732 | Identity: 0.418732 |
# Training epoch: 4 [200/995 (20%)] | D loss (A): 0.002598 | D loss (B): 0.251180 | G loss: 9.140031 | Consistency: 0.561842 | Identity: 0.561842 |
# Training epoch: 4 [300/995 (30%)] | D loss (A): 0.015608 | D loss (B): 0.250677 | G loss: 6.505641 | Consistency: 0.390907 | Identity: 0.390907 |
# Training epoch: 4 [400/995 (40%)] | D loss (A): 0.001893 | D loss (B): 0.253526 | G loss: 7.009380 | Consistency: 0.426364 | Identity: 0.426364 |
# Training epoch: 4 [500/995 (50%)] | D loss (A): 0.003155 | D loss (B): 0.250320 | G loss: 6.574128 | Consistency: 0.399130 | Identity: 0.399130 |
# Training epoch: 4 [600/995 (60%)] | D loss (A): 0.005136 | D loss (B): 0.250694 | G loss: 8.431844 | Consistency: 0.517108 | Identity: 0.517108 |
# Training epoch: 4 [700/995 (70%)] | D loss (A): 0.008720 | D loss (B): 0.250549 | G loss: 6.891738 | Consistency: 0.418090 | Identity: 0.418090 |
# Training epoch: 4 [800/995 (80%)] | D loss (A): 0.002258 | D loss (B): 0.250807 | G loss: 7.935155 | Consistency: 0.486796 | Identity: 0.486796 |
# Training epoch: 4 [900/995 (90%)] | D loss (A): 0.005537 | D loss (B): 0.250479 | G loss: 5.735163 | Consistency: 0.338513 | Identity: 0.338513 |
# Training epoch: 5 [0/995 (0%)] | D loss (A): 0.011633 | D loss (B): 0.250740 | G loss: 7.155982 | Consistency: 0.433365 | Identity: 0.433365 |
# Training epoch: 5 [100/995 (10%)] | D loss (A): 0.002612 | D loss (B): 0.250100 | G loss: 7.470901 | Consistency: 0.457573 | Identity: 0.457573 |
# Training epoch: 5 [200/995 (20%)] | D loss (A): 0.003803 | D loss (B): 0.250369 | G loss: 9.412819 | Consistency: 0.585057 | Identity: 0.585057 |
# Training epoch: 5 [300/995 (30%)] | D loss (A): 0.018599 | D loss (B): 0.250230 | G loss: 6.275888 | Consistency: 0.374911 | Identity: 0.374911 |
# Training epoch: 5 [400/995 (40%)] | D loss (A): 0.005103 | D loss (B): 0.250110 | G loss: 8.279723 | Consistency: 0.507723 | Identity: 0.507723 |
# Training epoch: 5 [500/995 (50%)] | D loss (A): 0.012644 | D loss (B): 0.251887 | G loss: 7.776602 | Consistency: 0.475473 | Identity: 0.475473 |
# Training epoch: 5 [600/995 (60%)] | D loss (A): 0.003198 | D loss (B): 0.250375 | G loss: 8.063623 | Consistency: 0.496311 | Identity: 0.496311 |
# Training epoch: 5 [700/995 (70%)] | D loss (A): 0.008492 | D loss (B): 0.250228 | G loss: 6.113943 | Consistency: 0.362808 | Identity: 0.362808 |
# Training epoch: 5 [800/995 (80%)] | D loss (A): 0.001724 | D loss (B): 0.250508 | G loss: 6.895093 | Consistency: 0.417833 | Identity: 0.417833 |
# Training epoch: 5 [900/995 (90%)] | D loss (A): 0.001545 | D loss (B): 0.250114 | G loss: 9.849072 | Consistency: 0.615843 | Identity: 0.615843 |
# Training epoch: 6 [0/995 (0%)] | D loss (A): 0.005255 | D loss (B): 0.250541 | G loss: 7.088218 | Consistency: 0.431337 | Identity: 0.431337 |
# Training epoch: 6 [100/995 (10%)] | D loss (A): 0.001431 | D loss (B): 0.250347 | G loss: 7.453816 | Consistency: 0.455582 | Identity: 0.455582 |
# Training epoch: 6 [200/995 (20%)] | D loss (A): 0.001696 | D loss (B): 0.250612 | G loss: 6.607651 | Consistency: 0.397851 | Identity: 0.397851 |
# Training epoch: 6 [300/995 (30%)] | D loss (A): 0.001715 | D loss (B): 0.250185 | G loss: 7.649022 | Consistency: 0.468282 | Identity: 0.468282 |
# Training epoch: 6 [400/995 (40%)] | D loss (A): 0.001454 | D loss (B): 0.255510 | G loss: 5.868173 | Consistency: 0.350568 | Identity: 0.350568 |
# Training epoch: 6 [500/995 (50%)] | D loss (A): 0.003899 | D loss (B): 0.250332 | G loss: 9.278562 | Consistency: 0.578017 | Identity: 0.578017 |
# Training epoch: 6 [600/995 (60%)] | D loss (A): 0.003067 | D loss (B): 0.250171 | G loss: 7.408854 | Consistency: 0.450915 | Identity: 0.450915 |
# Training epoch: 6 [700/995 (70%)] | D loss (A): 0.003801 | D loss (B): 0.250087 | G loss: 10.369779 | Consistency: 0.650468 | Identity: 0.650468 |
# Training epoch: 6 [800/995 (80%)] | D loss (A): 0.005969 | D loss (B): 0.250085 | G loss: 7.658653 | Consistency: 0.465702 | Identity: 0.465702 |
# Training epoch: 6 [900/995 (90%)] | D loss (A): 0.009989 | D loss (B): 0.250149 | G loss: 7.061676 | Consistency: 0.431095 | Identity: 0.431095 |
# Training epoch: 7 [0/995 (0%)] | D loss (A): 0.026640 | D loss (B): 0.250034 | G loss: 6.845934 | Consistency: 0.417158 | Identity: 0.417158 |
# Training epoch: 7 [100/995 (10%)] | D loss (A): 0.001188 | D loss (B): 0.250026 | G loss: 5.908171 | Consistency: 0.351387 | Identity: 0.351387 |
# Training epoch: 7 [200/995 (20%)] | D loss (A): 0.002529 | D loss (B): 0.250311 | G loss: 6.980516 | Consistency: 0.422521 | Identity: 0.422521 |
# Training epoch: 7 [400/995 (40%)] | D loss (A): 0.001182 | D loss (B): 0.250030 | G loss: 6.802657 | Consistency: 0.411687 | Identity: 0.411687 |
# Training epoch: 7 [500/995 (50%)] | D loss (A): 0.007247 | D loss (B): 0.250071 | G loss: 8.318507 | Consistency: 0.512373 | Identity: 0.512373 |
# Training epoch: 7 [600/995 (60%)] | D loss (A): 0.002125 | D loss (B): 0.250130 | G loss: 6.274133 | Consistency: 0.377150 | Identity: 0.377150 |
# Training epoch: 7 [700/995 (70%)] | D loss (A): 0.001045 | D loss (B): 0.250192 | G loss: 7.820934 | Consistency: 0.478045 | Identity: 0.478045 |
# Training epoch: 7 [800/995 (80%)] | D loss (A): 0.006236 | D loss (B): 0.250117 | G loss: 11.247709 | Consistency: 0.708881 | Identity: 0.708881 |
# Training epoch: 7 [900/995 (90%)] | D loss (A): 0.003090 | D loss (B): 0.250516 | G loss: 13.197780 | Consistency: 0.836987 | Identity: 0.836987 |
# Training epoch: 8 [0/995 (0%)] | D loss (A): 0.000835 | D loss (B): 0.250150 | G loss: 7.134200 | Consistency: 0.433599 | Identity: 0.433599 |
# Training epoch: 8 [100/995 (10%)] | D loss (A): 0.002349 | D loss (B): 0.250180 | G loss: 6.961976 | Consistency: 0.422333 | Identity: 0.422333 |
# Training epoch: 8 [200/995 (20%)] | D loss (A): 0.003984 | D loss (B): 0.250628 | G loss: 9.301976 | Consistency: 0.578490 | Identity: 0.578490 |
# Training epoch: 8 [300/995 (30%)] | D loss (A): 0.004458 | D loss (B): 0.250371 | G loss: 6.813181 | Consistency: 0.411607 | Identity: 0.411607 |
# Training epoch: 8 [400/995 (40%)] | D loss (A): 0.005970 | D loss (B): 0.250937 | G loss: 7.438439 | Consistency: 0.455696 | Identity: 0.455696 |
# Training epoch: 8 [500/995 (50%)] | D loss (A): 0.022647 | D loss (B): 0.251012 | G loss: 5.204673 | Consistency: 0.308501 | Identity: 0.308501 |
# Training epoch: 8 [600/995 (60%)] | D loss (A): 0.011403 | D loss (B): 0.250401 | G loss: 7.599845 | Consistency: 0.465712 | Identity: 0.465712 |
# Training epoch: 8 [700/995 (70%)] | D loss (A): 0.008887 | D loss (B): 0.250274 | G loss: 8.280437 | Consistency: 0.506902 | Identity: 0.506902 |
# Training epoch: 8 [800/995 (80%)] | D loss (A): 0.005792 | D loss (B): 0.250523 | G loss: 8.239811 | Consistency: 0.507083 | Identity: 0.507083 |
# Training epoch: 8 [900/995 (90%)] | D loss (A): 0.003515 | D loss (B): 0.250733 | G loss: 9.097322 | Consistency: 0.561543 | Identity: 0.561543 |
# Training epoch: 9 [0/995 (0%)] | D loss (A): 0.032190 | D loss (B): 0.250237 | G loss: 7.389096 | Consistency: 0.450725 | Identity: 0.450725 |
# Training epoch: 9 [100/995 (10%)] | D loss (A): 0.006784 | D loss (B): 0.250048 | G loss: 6.848827 | Consistency: 0.417093 | Identity: 0.417093 |
# Training epoch: 9 [200/995 (20%)] | D loss (A): 0.003619 | D loss (B): 0.250087 | G loss: 7.617227 | Consistency: 0.465046 | Identity: 0.465046 |
# Training epoch: 9 [300/995 (30%)] | D loss (A): 0.006601 | D loss (B): 0.250158 | G loss: 7.482631 | Consistency: 0.453670 | Identity: 0.453670 |
# Training epoch: 9 [400/995 (40%)] | D loss (A): 0.001838 | D loss (B): 0.250633 | G loss: 7.631127 | Consistency: 0.465215 | Identity: 0.465215 |
# Training epoch: 9 [500/995 (50%)] | D loss (A): 0.003081 | D loss (B): 0.251043 | G loss: 5.249346 | Consistency: 0.308554 | Identity: 0.308554 |
# Training epoch: 9 [600/995 (60%)] | D loss (A): 0.001895 | D loss (B): 0.250658 | G loss: 7.451535 | Consistency: 0.455923 | Identity: 0.455923 |
# Training epoch: 9 [700/995 (70%)] | D loss (A): 0.002315 | D loss (B): 0.250591 | G loss: 8.269661 | Consistency: 0.510221 | Identity: 0.510221 |
# Training epoch: 9 [800/995 (80%)] | D loss (A): 0.001479 | D loss (B): 0.250668 | G loss: 5.256867 | Consistency: 0.309873 | Identity: 0.309873 |
# Training epoch: 9 [900/995 (90%)] | D loss (A): 0.002022 | D loss (B): 0.251446 | G loss: 6.823371 | Consistency: 0.414204 | Identity: 0.414204 |
# Training epoch: 10 [0/995 (0%)] | D loss (A): 0.014653 | D loss (B): 0.250478 | G loss: 7.503078 | Consistency: 0.457669 | Identity: 0.457669 |
# Training epoch: 10 [100/995 (10%)] | D loss (A): 0.002640 | D loss (B): 0.250932 | G loss: 6.477595 | Consistency: 0.391712 | Identity: 0.391712 |
# Training epoch: 10 [200/995 (20%)] | D loss (A): 0.001704 | D loss (B): 0.250340 | G loss: 9.365485 | Consistency: 0.583535 | Identity: 0.583535 |
# Training epoch: 10 [300/995 (30%)] | D loss (A): 0.001226 | D loss (B): 0.250199 | G loss: 12.231794 | Consistency: 0.774390 | Identity: 0.774390 |
# Training epoch: 10 [400/995 (40%)] | D loss (A): 0.001067 | D loss (B): 0.250064 | G loss: 9.122959 | Consistency: 0.566910 | Identity: 0.566910 |
# Training epoch: 10 [500/995 (50%)] | D loss (A): 0.000810 | D loss (B): 0.250249 | G loss: 6.657804 | Consistency: 0.401885 | Identity: 0.401885 |
# Training epoch: 10 [600/995 (60%)] | D loss (A): 0.001807 | D loss (B): 0.250773 | G loss: 6.433721 | Consistency: 0.385871 | Identity: 0.385871 |
# Training epoch: 10 [700/995 (70%)] | D loss (A): 0.015204 | D loss (B): 0.250415 | G loss: 7.484358 | Consistency: 0.459874 | Identity: 0.459874 |
# Training epoch: 10 [800/995 (80%)] | D loss (A): 0.002513 | D loss (B): 0.250210 | G loss: 7.471973 | Consistency: 0.457609 | Identity: 0.457609 |
# Training epoch: 10 [900/995 (90%)] | D loss (A): 0.003242 | D loss (B): 0.250388 | G loss: 6.873837 | Consistency: 0.416482 | Identity: 0.416482 |

# %%
testimg_path = 'apple2orange/testA'
img_list = os.listdir(testimg_path)
img_idx = np.random.randint(len(img_list))
test_imgA = Image.open(os.path.join(testimg_path, img_list[img_idx]))
to_tensor = transforms.ToTensor()
test_imgA_tensor = to_tensor(test_imgA).unsqueeze(0).cuda()
fake_test_B = G_A2B(test_imgA_tensor)
Image.fromarray((fake_test_B * 256.).clamp(min=0., max=255.).data.cpu().squeeze().numpy().transpose(1, 2, 0).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8F0FF075F8>

# %%
test_imgA
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F8F0FF1BCC0>

# %% [markdown]
# # 課題
#
#
# *   データセットを変更して学習してみましょう．
# *   学習する際に使用しているCycle consistency lossやIdentity lossを使用しない場合，どのような結果が得られるか確認してみましょう．
