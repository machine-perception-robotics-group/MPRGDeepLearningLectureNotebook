# %% [markdown]
# # Generative Adversarial Networks（GAN）
#
# ---
# ## 目的
# GAN (Generative Adversarial Networks) [1]を構築し，敵対的学習による画像生成の仕組みを理解する．`autoencoder.ipynb`・`vae.ipynb`とは異なり，画像を入力とせず，潜在変数のみから画像を生成する点に注目する．
#
# [1] Ian Goodfellow, Jean Pouget-Abadie, Mehdi Mirza, Bing Xu, David Warde-Farley, Sherjil Ozair, Aaron Courville and Yoshua Bengio, "Generative Adversarial Nets," NIPS, 2014.

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートしたのち，GPUを使用した計算が可能かどうかを確認する．

# %%
from time import time
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

# %% [markdown]
# ## ネットワークの構築
# GANは，**Generator**（生成器）と**Discriminator**（識別器）と呼ばれる2つのネットワークによって構成される生成モデルです．
#
# Generatorは，正規分布からサンプリングした潜在変数を入力して画像を生成するネットワークです．Generatorは，綺麗な画像を生成することでDiscriminatorを欺くことを目的としています．
#
# 一方でDiscriminatorは，実画像（訓練画像）またはGeneratorが生成した画像のどちらかを入力して，入力されたデータが本物か偽物かを判別するネットワークです．Discriminatorは，Generatorの生成した画像を見破ることを目的としています．
#
# GANの最終的な目的は，実画像$x$の確率分布$p_{data}(x)$と，Generatorが生成する画像の確率分布$p_{g}(x)$が一致することです．つまり，$p_{data}(x)=p_{g}(x)$が成立したとき，Discriminatorは本物か偽物か判別できなくなっていると言えます．
#
# ### ネットワーク構造
# Generator・Discriminatorは，全結合層2層とReLU（Discriminatorは Leaky ReLU）で構成します．層のサイズは，Generatorでは（`潜在変数 → 256 → 784`）として構築します．Discriminatorはその対称（`784 → 256 → 1`）とします．Generatorの最終層には，出力する画素値を実画像と同じ[0, 1]の範囲に収めるためSigmoid関数を適用します．

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=100):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(latent_dim, 256), nn.ReLU(inplace=True),
            nn.Linear(256, 28 * 28), nn.Sigmoid(),
        )

    def forward(self, z):
        return self.layer(z)


class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Sequential(
            nn.Linear(28 * 28, 256), nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),  # Sigmoidは適用しない（BCEWithLogitsLossで内部的に適用する）
        )

    def forward(self, x):
        return self.layer(x)

# %% [markdown]
# ## データセットと最適化関数
# データセットにはMNISTを使用します．最適化関数はAdam optimizerを使用し，学習率$2\times 10^{-4}$，betaの値を$(0.5, 0.999)$として学習します．潜在変数の次元数（`latent_dim`）は，以降のDC-GAN・Conditional GANでも共通して`100`を使用します．

# %%
mnist_data = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
train_loader = DataLoader(mnist_data, batch_size=100, shuffle=True)

latent_dim = 100
G = Generator(latent_dim=latent_dim).to(device)
D = Discriminator().to(device)
opt_g = torch.optim.Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
opt_d = torch.optim.Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %% [markdown]
# ## GANの学習
# GANの最適化式は以下の通りです．
#
# $$
# \min_{G}\max_{D}V(D, G) = \mathbb{E}_{x\sim p_{data}(x)}\left[\log D(x)\right] + \mathbb{E}_{z\sim p(z)}\left[\log\left(1 - D(G(z))\right)\right]
# $$
#
# ここで，$x$は実画像，$G(z)$がGeneratorの生成した画像です．学習にはbinary cross entropyを用い，Discriminatorは実画像を1，生成画像を0に近づけるように学習します．一方Generatorは，生成した画像をDiscriminatorに1（本物）と誤識別させたいため，1に近づくように学習します．これによりGANの敵対的学習を実現します．
#
# `n_critic`は，Generatorを1回更新する間にDiscriminatorを何回更新するかを指定する値です．Discriminatorを複数回更新した後にGeneratorを1回更新することで，モード崩壊（Generatorが特定の画像しか生成できなくなる問題）を防止します．</cell id="cell-7">

# %%
epoch_num = 20
n_critic = 1
criterion = nn.BCEWithLogitsLoss().to(device)

G.train()
D.train()
start = time()
for epoch in range(1, epoch_num + 1):
    for idx, (real_x, _) in enumerate(train_loader):
        real_x = real_x.view(real_x.size(0), -1).to(device)
        batch = real_x.size(0)
        flag_real = torch.ones(batch, 1).to(device)
        flag_fake = torch.zeros(batch, 1).to(device)

        for _ in range(n_critic):
            z = torch.randn(batch, latent_dim).to(device)
            fake_x = G(z)

            out_real = D(real_x)
            out_fake = D(fake_x.detach())
            dis_loss = criterion(out_real, flag_real) + criterion(out_fake, flag_fake)

            opt_d.zero_grad()
            dis_loss.backward()
            opt_d.step()

        z = torch.randn(batch, latent_dim).to(device)
        fake_x = G(z)
        out_gen = D(fake_x)
        gen_loss = criterion(out_gen, flag_real)

        opt_g.zero_grad()
        gen_loss.backward()
        opt_g.step()

    print(f'epoch: {epoch}, D loss: {dis_loss.item():.4f}, G loss: {gen_loss.item():.4f}, elapsed_time: {time() - start:.4f}')

# %% [markdown]
# ## 学習したGeneratorによる画像生成
# 正規分布に従う乱数`z`を生成し，Generatorへ入力することで画像を生成します．適切に学習が行われていれば，0〜9の数字の画像が生成されます．

# %%
num_generate = 100
z = torch.randn(num_generate, latent_dim).to(device)

G.eval()
with torch.no_grad():
    test_img = G(z)

test_img = test_img.view(num_generate, 28, 28).cpu().numpy()

fig = plt.figure(figsize=(10, 10))
for i, im in enumerate(test_img):
    ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(im, cmap='gray')
plt.show()

# %% [markdown]
# ## 課題
#
# 1. 潜在変数の次元数（`latent_dim`）を100次元から減らした場合，または増やした場合，生成される画像はどのように変化するでしょうか．
# 2. `n_critic`の値を変更して学習し，Generator・Discriminatorそれぞれの学習の安定性がどのように変化するか確認してください．
