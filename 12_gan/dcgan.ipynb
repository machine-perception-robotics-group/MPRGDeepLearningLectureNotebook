# %% [markdown]
# # Deep Convolutional GAN（DC-GAN）
#
# ---
# ## 目的
# Deep Convolutional GAN (DC-GAN) [1]を構築し，畳み込み層を用いた画像生成の仕組みを理解する．`gan.ipynb`のGANとの違いに注目する．
#
# [1] Alec Radford, Luke Metz and Soumith Chintala, "Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks," ICLR, 2016.

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートしたのち，GPUを使用した計算が可能かどうかを確認する．

# %%
from time import time
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

# %% [markdown]
# ## ネットワークの構築
# `gan.ipynb`のGANは，全結合層とReLUのみで構成される非常にシンプルなネットワークでした．シンプルな反面，学習が不安定になったり，高解像度な画像生成が難しいという問題があります．
#
# DC-GANは，名前の通り畳み込み層を用いてネットワークを構築することで，オリジナルのGANより綺麗な画像を生成することを可能にした手法です．`gan.ipynb`のGANと比べて，以下の点が異なります．
#
# * 全結合層ではなく，畳み込み層（Generatorは転置畳み込み層）を用いる．PoolingではなくConvolution/Deconvolutionでダウンサンプリング・アップサンプリングを行う．
# * Batch Normalizationを利用する（Discriminatorの1層目と最終層は除く）．
# * Discriminatorの活性化関数にLeaky ReLUを使用する．
#
# Generator・Discriminatorともに4層の畳み込みで構成し，$1\times1 \to 4\times4 \to 8\times8 \to 16\times16 \to 32\times32$と，段階的に画像サイズを変化させます．そのため，本ノートブックではMNIST画像を$32\times32$にリサイズして使用します．潜在変数の次元数（`latent_dim`）は，`gan.ipynb`と同じ`100`を使用します．

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=100, out_ch=1):
        super().__init__()
        self.model = nn.Sequential(
            nn.ConvTranspose2d(latent_dim, 256, kernel_size=4, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(256), nn.ReLU(inplace=True),  # 1x1 -> 4x4

            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(128), nn.ReLU(inplace=True),  # 4x4 -> 8x8

            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64), nn.ReLU(inplace=True),  # 8x8 -> 16x16

            nn.ConvTranspose2d(64, out_ch, kernel_size=4, stride=2, padding=1, bias=False),
            nn.Sigmoid(),  # 16x16 -> 32x32，画素値を[0, 1]の範囲に収める
        )

    def forward(self, z):
        return self.model(z)


class Discriminator(nn.Module):
    def __init__(self, in_ch=1):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(in_ch, 64, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),  # 32x32 -> 16x16（1層目はBNを適用しない）

            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(128), nn.LeakyReLU(0.2, inplace=True),  # 16x16 -> 8x8

            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(256), nn.LeakyReLU(0.2, inplace=True),  # 8x8 -> 4x4

            nn.Conv2d(256, 1, kernel_size=4, stride=1, padding=0, bias=False),  # 4x4 -> 1x1（最終層もBNを適用しない）
        )

    def forward(self, x):
        return self.model(x).view(-1, 1)

# %% [markdown]
# ## データセットと最適化関数
# データセットにはMNISTを使用します．最適化関数・学習率は`gan.ipynb`と同じくAdam optimizer（学習率$2\times 10^{-4}$，betaの値$(0.5, 0.999)$）を使用します．重みパラメータは，平均0，標準偏差0.02の正規分布で初期化します．

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname in ('Conv2d', 'ConvTranspose2d'):
        nn.init.normal_(m.weight.data, 0.0, 0.02)


transform = transforms.Compose([transforms.Resize((32, 32)), transforms.ToTensor()])
mnist_data = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = DataLoader(mnist_data, batch_size=128, shuffle=True)

latent_dim = 100
G = Generator(latent_dim=latent_dim, out_ch=1).to(device)
D = Discriminator(in_ch=1).to(device)
G.apply(weights_init)
D.apply(weights_init)

opt_g = torch.optim.Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
opt_d = torch.optim.Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %% [markdown]
# ## DC-GANの学習
# 学習の手順自体は`gan.ipynb`のGANと同じため，詳細な説明は割愛します．Generator・Discriminatorへの入力・出力が，ベクトルではなく$(C, H, W)$の特徴マップになる点にのみ注意してください．

# %%
epoch_num = 20
n_critic = 1
criterion = nn.BCEWithLogitsLoss().to(device)

G.train()
D.train()
start = time()
for epoch in range(1, epoch_num + 1):
    for idx, (real_x, _) in enumerate(train_loader):
        real_x = real_x.to(device)
        batch = real_x.size(0)
        flag_real = torch.ones(batch, 1).to(device)
        flag_fake = torch.zeros(batch, 1).to(device)

        for _ in range(n_critic):
            z = torch.randn(batch, latent_dim, 1, 1).to(device)
            fake_x = G(z)

            out_real = D(real_x)
            out_fake = D(fake_x.detach())
            dis_loss = criterion(out_real, flag_real) + criterion(out_fake, flag_fake)

            opt_d.zero_grad()
            dis_loss.backward()
            opt_d.step()

        z = torch.randn(batch, latent_dim, 1, 1).to(device)
        fake_x = G(z)
        out_gen = D(fake_x)
        gen_loss = criterion(out_gen, flag_real)

        opt_g.zero_grad()
        gen_loss.backward()
        opt_g.step()

    print(f'epoch: {epoch}, D loss: {dis_loss.item():.4f}, G loss: {gen_loss.item():.4f}, elapsed_time: {time() - start:.4f}')

# %% [markdown]
# ## 学習したGeneratorによる画像生成
# 正規分布に従う乱数`z`を生成し，Generatorへ入力することで画像を生成します．

# %%
num_generate = 100
z = torch.randn(num_generate, latent_dim, 1, 1).to(device)

G.eval()
with torch.no_grad():
    test_img = G(z)

test_img = test_img.view(num_generate, 32, 32).cpu().numpy()

fig = plt.figure(figsize=(10, 10))
for i, im in enumerate(test_img):
    ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(im, cmap='gray')
plt.show()

# %% [markdown]
# ## 課題
#
# 1. データセットをMNISTからCIFAR-10に変更して学習してみましょう（`out_ch=3`, `in_ch=3`に変更する必要があります）．
# 2. 2つの潜在変数を線形補間して画像を生成した場合，生成される画像はどのように変化するか確認してください．
