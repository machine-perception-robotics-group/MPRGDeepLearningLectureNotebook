# %% [markdown]
# # データ拡張（Data Augmentation）
#
#
# ---
# ## 目的
# PyTorch実装による畳み込みニューラルネットワーク（CNN）を用いてCIFAR10データセットに対する10クラスの物体認識を行う．
# ネットワークの定義や学習・評価に関するプログラムの構成は`cifar_cnn.ipynb`と同様であるため，詳細な説明はそちらを参照して頂きたい．このページでは，`torchvision.transforms`を用いたデータ拡張（Data Augmentation）について中心的に説明する．

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートする．
#
# ### GPUの確認
# GPUを使用した計算が可能かどうかを確認します．
#
# `torch.cuda.is_available()`でGPUが利用可能かどうかを確認し，利用可能であれば`'cuda'`，利用できない場合は`'cpu'`を指定した`device`を作成します．
#
# `device: cuda`と表示されれば，GPUを使用した計算をPyTorchで行うことが可能です．
# `device: cpu`となっている場合は，「ラインタイム --> ランタイムの変更」からGPUを選択してください．

# %%
from time import time   # 時間計測を行うモジュール

import torch            # 深層学習のモジュール（PyTorch）
import torch.nn as nn

import torchvision      # PyTorchで画像認識に使用するネットワークやデータセットを利用するためのモジュール
import torchvision.transforms as transforms

import torchsummary     # PyTorchで作成したネットワークモデルの詳細を表示するモジュール

# GPUの確認
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

# %% [markdown]
# ## Data Augmentationとは
#
# Data Augmentation（データ拡張）とは，学習データに対して切り抜き・反転・回転・色調変換などのランダムな変換を加えることで，元のデータセットには存在しない多様なパターンの画像を人工的に作り出し，学習に利用する手法です．
#
# 深層学習モデルは大量のデータを用いて学習することで高い性能を発揮しますが，収集できるデータの量には限りがあります．データ数が少ない場合，モデルが学習データの細かい特徴まで過剰に適合してしまう**過学習（Overfitting）**が起こりやすくなります．
#
# Data Augmentationを用いることで，見かけ上のデータ数を増やし，様々なバリエーションの画像に対してモデルを学習させることができるため，過学習を抑制し，未知のデータに対する認識性能（汎化性能）を向上させる効果が期待できます．

# %% [markdown]
# ## transforms.Composeによる前処理・Augmentationの定義
#
# `torchvision.transforms`では，複数の前処理・Augmentation処理を`transforms.Compose()`にリストとして渡すことで，一連の処理をまとめて定義することができます．
# `Compose`に渡された処理は，リストの先頭から順番に画像データへ適用されます．
#
# 学習およびテスト画像に対する前処理は，それぞれ`transform_train`，`transform_test`という変数として定義します．
# なお，Data Augmentationはあくまでも学習（Train）データに対して有効な処理であり，評価（Test）データに対しては通常適用しません．評価は本来のデータ分布に対して行う必要があるためです．

# %% [markdown]
# ### 代表的なAugmentation手法
#
# `torchvision.transforms`には，様々なAugmentation・前処理のためのクラスが用意されています．代表的なものを以下に示します．
#
# | クラス | 説明 |
# | --- | --- |
# | `ToTensor()` | 画像データ（Numpy arrayまたはPIL Image）を`torch.Tensor`型に変換し，画素値を`[0, 255]`から`[0.0, 1.0]`に正規化する |
# | `Normalize(mean, std)` | 各チャンネルを指定した平均・標準偏差で正規化する |
# | `RandomCrop(size, padding)` | 画像の周囲を`padding`分パディングした後，ランダムな位置から`size`の大きさで切り抜く |
# | `RandomHorizontalFlip(p)` | 確率`p`で画像を左右反転する |
# | `RandomRotation(degrees)` | `-degrees`〜`degrees`の範囲でランダムに画像を回転する |
# | `ColorJitter(brightness, contrast, saturation, hue)` | 明るさ・コントラスト・彩度・色相をランダムに変化させる |
# | `RandomErasing(p)` | 確率`p`で画像の一部を矩形状に塗りつぶす（Cutoutと同様の効果） |
#
# これらの処理を組み合わせることで，様々なバリエーションのAugmentationを定義することができます．他の処理については，[torchvision.transformsのリファレンスページ](https://pytorch.org/vision/stable/transforms.html)を参照してください．

# %% [markdown]
# ### augmentationの定義例
#
# まず，Augmentationなしの場合は，`ToTensor()`のみを`Compose`に渡します．
#
# Augmentationを行う場合は，`RandomCrop`や`RandomHorizontalFlip`などの処理を`ToTensor()`より前に追加します．下記の例では，`RandomCrop(32, padding=4)`と`RandomHorizontalFlip()`を追加しています．

# %%
# augmentationなし
transform_train_noaug = transforms.Compose([transforms.ToTensor()])

# augmentationあり
transform_train_aug = transforms.Compose([transforms.RandomCrop(32, padding=4),
                                           transforms.RandomHorizontalFlip(),
                                           transforms.ToTensor()])

# テストデータにはAugmentationを適用しない
transform_test = transforms.Compose([transforms.ToTensor()])

# %% [markdown]
# ### Augmentationの効果を可視化する
#
# 実際に定義したAugmentationによって，画像がどのように変換されるかを確認してみます．
# 同じ画像に対して`transform_train_aug`を複数回適用し，得られる画像を比較することで，Augmentationによって画像がランダムに変化している様子を確認することができます．

# %%
import matplotlib.pyplot as plt

# Augmentationを確認するため，前処理を指定せずにCIFAR10を読み込む（PIL Image形式のまま）
raw_data = torchvision.datasets.CIFAR10(root="./", train=True, download=True)
sample_image, _ = raw_data[0]  # PIL Image

cols = 6
fig = plt.figure(figsize=(14, 2.4))

# オリジナル画像
ax = fig.add_subplot(1, cols, 1)
ax.imshow(sample_image)
ax.set_title('original')
ax.set_axis_off()

# Augmentationを複数回適用した結果
for i in range(1, cols):
    augmented_image = transform_train_aug(sample_image)
    ax = fig.add_subplot(1, cols, i + 1)
    ax.imshow(augmented_image.permute(1, 2, 0))  # [C, H, W] -> [H, W, C]
    ax.set_title(f'augmented {i}')
    ax.set_axis_off()

plt.show()

# %% [markdown]
# ### データセットの読み込み
#
# 上で定義した`transform_train_aug`（またはAugmentationを行わない場合は`transform_train_noaug`）と`transform_test`を用いて，CIFAR10データセットを読み込みます．

# %%
# 使用するtransformを指定（Augmentationあり/なしを切り替える場合はここを変更する）
transform_train = transform_train_aug

train_data = torchvision.datasets.CIFAR10(root="./", train=True, transform=transform_train, download=True)
test_data = torchvision.datasets.CIFAR10(root="./", train=False, transform=transform_test, download=True)

print(train_data)
print(test_data)

# %% [markdown]
# ## ネットワークモデルの定義
#
# 畳み込みニューラルネットワークを定義します．
# ここでは，畳み込み層2層，全結合層3層から構成されるネットワークを使用します．

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, 2)
        self.l1 = nn.Linear(8 * 8 * 32, 1024)
        self.l2 = nn.Linear(1024, 1024)
        self.l3 = nn.Linear(1024, 10)

    def forward(self, x):
        h = self.pool(self.relu(self.conv1(x)))
        h = self.pool(self.relu(self.conv2(h)))
        h = h.view(h.size()[0], -1)
        h = self.relu(self.l1(h))
        h = self.relu(self.l2(h))
        h = self.l3(h)
        return h

# %% [markdown]
# ## ネットワークの作成
# 上で定義したネットワークを作成します．`.to(device)`を用いて，ネットワークを`device`で指定したデバイスへ配置します．

# %%
model = CNN()
model = model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

torchsummary.summary(model, (3, 32, 32), device=device.type)

# %% [markdown]
# ## 学習
#
# CIFAR10データセットと作成したネットワークを用いて学習を行います．

# %%
batch_size = 100
epoch_num = 10

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)

criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)

model.train()

train_start = time()
for epoch in range(1, epoch_num+1):
    sum_loss = 0.0
    count = 0

    for image, label in train_loader:
        image = image.to(device)
        label = label.to(device)

        y = model(image)
        loss = criterion(y, label)

        model.zero_grad()
        loss.backward()
        optimizer.step()

        sum_loss += loss.item()
        pred = torch.argmax(y, dim=1)
        count += torch.sum(pred == label)

    print("epoch: {}, mean loss: {}, mean accuracy: {}, elapsed time: {}".format(epoch, sum_loss/len(train_loader), count.item()/len(train_data), time() - train_start))

# %% [markdown]
# ## テスト
# 学習したネットワークモデルを用いて評価を行います．

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size=100, shuffle=False)

model.eval()

count = 0
with torch.no_grad():
    for image, label in test_loader:
        image = image.to(device)
        label = label.to(device)

        y = model(image)

        pred = torch.argmax(y, dim=1)
        count += torch.sum(pred == label)

print("test accuracy: {}".format(count.item() / len(test_data)))

# %% [markdown]
# ---
# ## torchvision.transforms.v2 について
#
# ここまでは`torchvision.transforms`（以下，v1）を用いてData Augmentationを実装してきましたが，torchvisionには新しいバージョンのtransforms APIである**`torchvision.transforms.v2`**が用意されています．
#
# v2はtorchvision 0.15で導入され，0.17以降は安定版として利用可能になっており，現在はv2の使用が推奨されています．v1との主な違いは以下の通りです．
#
# * **高速化**：内部実装が最適化されており，特に`torch.Tensor`に対する処理がv1よりも高速です．
# * **画像以外のデータへの対応**：物体検出のbounding boxやセグメンテーションのmaskなど，画像以外のデータも画像と同時に一貫して変換することができます（`tv_tensors`という仕組みを利用します）．
# * **バッチ単位のAugmentation**：`MixUp`や`CutMix`など，複数の画像・ラベルを組み合わせる新しいAugmentation手法が追加されています．
#
# v1で使用してきた`RandomCrop`や`RandomHorizontalFlip`などのクラスは，v2でも同じ名前でほぼそのまま利用可能です．
# 一方で，`ToTensor()`はv2では非推奨となっており，代わりに**`ToImage()`**（画像データをTensor形式に変換）と**`ToDtype(dtype, scale=True)`**（型変換と画素値の正規化）を組み合わせて使用します．

# %%
from torchvision.transforms import v2

# v1と同じ内容のAugmentationをv2で定義する
transform_train_aug_v2 = v2.Compose([
    v2.RandomCrop(32, padding=4),
    v2.RandomHorizontalFlip(),
    v2.ToImage(),                            # 画像をTensor形式に変換（v1のToTensor()の前半に相当）
    v2.ToDtype(torch.float32, scale=True),   # float32型に変換し，画素値を[0, 255]->[0.0, 1.0]に正規化
])

transform_test_v2 = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
])

# %% [markdown]
# v1の場合と同様に，実際にv2のAugmentationを適用した画像を確認してみます．

# %%
cols = 6
fig = plt.figure(figsize=(14, 2.4))

ax = fig.add_subplot(1, cols, 1)
ax.imshow(sample_image)
ax.set_title('original')
ax.set_axis_off()

for i in range(1, cols):
    augmented_image = transform_train_aug_v2(sample_image)
    ax = fig.add_subplot(1, cols, i + 1)
    ax.imshow(augmented_image.permute(1, 2, 0))
    ax.set_title(f'augmented {i}')
    ax.set_axis_off()

plt.show()

# %% [markdown]
# ### バッチ単位のAugmentation：MixUpとCutMix
#
# v2から追加された特徴的なAugmentation手法として，**MixUp**と**CutMix**があります．
# これらはこれまで紹介してきた1枚の画像に対する変換とは異なり，**ミニバッチ内の2枚の画像とラベルを混合する**ことで新たな学習サンプルを作り出す手法です．
#
# * **MixUp**：2枚の画像を一定の割合で混ぜ合わせ（ピクセル値を線形補間），ラベルも同じ割合で混合する
# * **CutMix**：一方の画像の一部の領域をもう一方の画像で置き換え，ラベルは置き換えた面積の割合に応じて混合する
#
# MixUp・CutMixを適用すると，ラベルは元のクラス番号ではなく，クラスごとの割合を表すソフトラベルに変換されます．近年のPyTorchの`nn.CrossEntropyLoss()`はソフトラベルに対応しているため，通常の学習ループにそのまま組み込むことができます．

# %%
num_classes = 10
cutmix = v2.CutMix(num_classes=num_classes)
mixup = v2.MixUp(num_classes=num_classes)
cutmix_or_mixup = v2.RandomChoice([cutmix, mixup])  # 1バッチごとにランダムにどちらかを適用

# ミニバッチを1つ取り出して確認する
images, labels = next(iter(train_loader))
print('元のラベル:', labels[:4])

images, labels = cutmix_or_mixup(images, labels)
print('MixUp/CutMix適用後の画像サイズ:', images.shape)
print('MixUp/CutMix適用後のラベル（ソフトラベル）:', labels[:4])

# %% [markdown]
# 学習ループに組み込む場合は，`train_loader`からミニバッチを取り出した直後に`cutmix_or_mixup`を適用してからネットワークへ入力します．
#
# ```python
# for image, label in train_loader:
#     image, label = cutmix_or_mixup(image, label)
#     image = image.to(device)
#     label = label.to(device)
#
#     y = model(image)
#     loss = criterion(y, label)
#     ...
# ```
#
# v2のより詳しい使い方については，[torchvision.transforms.v2のリファレンスページ](https://pytorch.org/vision/stable/transforms.html)を参照してください．

# %% [markdown]
# ## 課題
#
# 1. AugmentationありとなしでCIFAR10の認識精度を比較してみましょう．
#
#     「データセットの読み込み」セルにある
#
#     ```python
#     transform_train = transform_train_aug
#     ```
#
#     の行を`transform_train = transform_train_noaug`に変更して再度学習・評価を行い，テスト精度にどのような違いが生じるか確認してみましょう．
#
# 2. Data Augmentationの種類を追加して学習を行いましょう．
#
#     ヒント：学習時に使用するData Augmentationは`transform_train_aug`の部分で変更できます．
#
#     ```python
#     transform_train_aug = transforms.Compose([(この部分に使用するAugmentationの処理を追加),
#                                                transforms.ToTensor()])
#     ```
#
#     PyTorch（torchvision）で使用可能な変換は[こちらのページ](https://pytorch.org/vision/stable/transforms.html)にまとめられています．
#
# 3. MixUpまたはCutMixを学習ループに組み込み，認識精度への影響を確認してみましょう．
#
#     上で紹介した`cutmix_or_mixup`を学習ループに組み込み，v1のAugmentationのみを使った場合と比べてテスト精度がどのように変化するか確認してみましょう．
